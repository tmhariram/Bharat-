# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df=df.drop('Id',axis=1)

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
sns.countplot(data=df,x='Species')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
sns.pairplot(df,hue='Species')

# %%
sns.scatterplot(data=df,x='SepalLengthCm',y='SepalWidthCm',hue='Species')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.scatterplot(data=df,x='PetalLengthCm',y='PetalWidthCm',hue='Species')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df['Species'].describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: Species, dtype: object

# %%
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
X=df.drop('Species',axis=1)
y=df['Species']

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import plot_confusion_matrix,classification_report,accuracy_score,confusion_matrix ,ConfusionMatrixDisplay

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,random_state=31)

# %%
log_model=LogisticRegression(max_iter=1000)
knn_model=KNeighborsClassifier()
svc_model=SVC()
dtc_model=DecisionTreeClassifier()
rfc_model=RandomForestClassifier()

# %%
log_model.fit(X_train,y_train)
knn_model.fit(X_train,y_train)
svc_model.fit(X_train,y_train)
dtc_model.fit(X_train,y_train)
rfc_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
accuracy_scores=[]

# %%
model_list1=[log_model,knn_model,svc_model,dtc_model,rfc_model]
for model in model_list1:
    preds=model.predict(X_test)
    a=accuracy_score(y_test,preds)
    accuracy_scores.append(a)
    print(str(model))
    print(classification_report(y_test,preds))
    cn=confusion_matrix(y_test,preds)
    Con=ConfusionMatrixDisplay(cn,display_labels=model.classes_)
    Con.plot()
    plt.show()
# Out:
# LogisticRegression(max_iter=1000)
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.94      0.97        16
#  Iris-virginica       0.92      1.00      0.96        11
#
#        accuracy                           0.97        38
#       macro avg       0.97      0.98      0.97        38
#    weighted avg       0.98      0.97      0.97        38
# KNeighborsClassifier()
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.88      0.93        16
#  Iris-virginica       0.85      1.00      0.92        11
#
#        accuracy                           0.95        38
#       macro avg       0.95      0.96      0.95        38
#    weighted avg       0.96      0.95      0.95        38
# SVC()
#                  precision    recall  f1-score   support
#
# ...

# %%
accuracy_scores
# Out:
# [0.9736842105263158,
#  0.9473684210526315,
#  0.9473684210526315,
#  0.9473684210526315,
#  0.9736842105263158]

# %%
pd.DataFrame({'Models':['log_model','knn_model','svc_model','dtc_model','rfc_model'],
              'Accuracy_Score':accuracy_scores})
# Out:
#       Models  Accuracy_Score
# 0  log_model        0.973684
# 1  knn_model        0.947368
# 2  svc_model        0.947368
# 3  dtc_model        0.947368
# 4  rfc_model        0.973684

# %%
new_data=[[4.9,3.0,1.4,0.2]]
log_model.predict(new_data)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Iris-setosa'], dtype=object)

# %% [markdown]
# ### From above observations,We can say that both 'Logistic Regression' and 'Random Forest Classifier' are performing well.We can ake any of those models for future prediction.
